# %% [markdown]
# # 목적 : 크롤링 + 엑셀을 활용한 데이터 처리 방법을 통해 필요한 데이터들을 저장하는 프로그램 만들기 + 단계별로 기능을 추가하며 조금더 프로그래밍에 익숙해지도록 한다 + 강의시에는 나오지않았던 문제를 직접 부딪치면서 문제점 혹은 나만의 필요한 기능을 추가해보도록 한다

# %% [markdown]
# 타이틀만 가져와서 출력하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')

for title in titles:
    title_text = title.select_one('span.subject_fixed')
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        print(title_text.get_text().strip())
# Out:
# 공부 13편 ㅡ 공부에서 중요한 것
# 뒤늦은 코로나 발병기
# 유니티로 간단한 게임 만들기
# 차에서 태블릿 사용 / 발열문제 해결책
# chatgpt에서 만든 마크다운을 마인드맵으로 간단하게 사용하기
# 싱가포르 한주간 여행 후기겸 개인적 팁
# [주간 코로나] 05월 5주 - 분석편 - (05. 28. - 06. 03.)
# 카시트 잘 태우기에 대한 이야기
# 미국 여행시 에어비앤비/민박은 주의하시길 바랍니다. - 도시법/규정 문제
# LED스트립만 연결해서 모니터 앰비언트를 만들어보자.
# [주간 코로나] 05월 5주 - 통계편 - <통권 147호>
# 상남자의 sata ssd2개 레이드0 비교기 (바이오스 vs 윈도우 2종)
# 대란에 ssd를 샀어요 방열판 꼭 달아야 하나요? 구리를 사야해요? 알루미늄 사야해요?
# 존윅4 불꽃샷건을 장난감총으로 따라해 보자
# [팁] 1분 안에 키보드 청소하는 법
# 써멀구리스의 중요성
# 포토샵 뺨치는 짭토샵 인공지능.GIF
# 외국 느낌의 데스크셋업 만들기
# 개인적인 영어 학습법입니다.
# 제네시스, 스마트폰을 차키로! 디지털 키 등록 방법 A to Z
# 인공지능으로 윤석열 제거하기.JPG
# Part3>영어 독해력을 키운다? 원서를 읽는 고행을 결심한 소수의 사람들에게
# 알리발 더스트건 간단사용후기
# 서울시 경계경보 담당자를 위한 경계경보 발령 강좌
# [코로나 정보] 코로나19 대응 지침 개정
# [코로나 단신] 05월 4주 - 분석편 -
# [주간 코로나] 05월 4주 - 통계편 - <통권 146호>
# Mac Arm CPU에서 WMware - Win11 ARM(가상) 활용방법(파일공유, 외부장치 연결 등)
# 울릉도 특산물 팁 - 호박 -

# %%
2단계: 타이틀 번호 추가하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0

for title in titles:
    title_text = title.select_one('span.subject_fixed')
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        print(index,title_text.get_text().strip())
# Out:
# 1 공부 13편 ㅡ 공부에서 중요한 것
# 2 뒤늦은 코로나 발병기
# 3 유니티로 간단한 게임 만들기
# 4 차에서 태블릿 사용 / 발열문제 해결책
# 5 chatgpt에서 만든 마크다운을 마인드맵으로 간단하게 사용하기
# 6 싱가포르 한주간 여행 후기겸 개인적 팁
# 7 [주간 코로나] 05월 5주 - 분석편 - (05. 28. - 06. 03.)
# 8 카시트 잘 태우기에 대한 이야기
# 9 미국 여행시 에어비앤비/민박은 주의하시길 바랍니다. - 도시법/규정 문제
# 10 LED스트립만 연결해서 모니터 앰비언트를 만들어보자.
# 11 [주간 코로나] 05월 5주 - 통계편 - <통권 147호>
# 12 상남자의 sata ssd2개 레이드0 비교기 (바이오스 vs 윈도우 2종)
# 13 대란에 ssd를 샀어요 방열판 꼭 달아야 하나요? 구리를 사야해요? 알루미늄 사야해요?
# 14 존윅4 불꽃샷건을 장난감총으로 따라해 보자
# 15 [팁] 1분 안에 키보드 청소하는 법
# 16 써멀구리스의 중요성
# 17 포토샵 뺨치는 짭토샵 인공지능.GIF
# 18 외국 느낌의 데스크셋업 만들기
# 19 개인적인 영어 학습법입니다.
# 20 제네시스, 스마트폰을 차키로! 디지털 키 등록 방법 A to Z
# 21 인공지능으로 윤석열 제거하기.JPG
# 22 Part3>영어 독해력을 키운다? 원서를 읽는 고행을 결심한 소수의 사람들에게
# 23 알리발 더스트건 간단사용후기
# 24 서울시 경계경보 담당자를 위한 경계경보 발령 강좌
# 25 [코로나 정보] 코로나19 대응 지침 개정
# 26 [코로나 단신] 05월 4주 - 분석편 -
# 27 [주간 코로나] 05월 4주 - 통계편 - <통권 146호>
# 28 Mac Arm CPU에서 WMware - Win11 ARM(가상) 활용방법(파일공유, 외부장치 연결 등)
# 29 울릉도 특산물 팁 - 호박 -

# %%
3단계: 타이틀별 댓글 수 추가하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0

for title in titles:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            print(index,title_text.get_text().strip(),"댓글수 :",title_replies.get_text())
        except Exception as e:
            if title_replies == None:
                print(index,title_text.get_text().strip(),"댓글수 :",0)
            continue
# Out:
# 1 공부 13편 ㅡ 공부에서 중요한 것 댓글수 : 0
# 2 뒤늦은 코로나 발병기 댓글수 : 9
# 3 유니티로 간단한 게임 만들기 댓글수 : 18
# 4 차에서 태블릿 사용 / 발열문제 해결책 댓글수 : 10
# 5 chatgpt에서 만든 마크다운을 마인드맵으로 간단하게 사용하기 댓글수 : 2
# 6 싱가포르 한주간 여행 후기겸 개인적 팁 댓글수 : 40
# 7 [주간 코로나] 05월 5주 - 분석편 - (05. 28. - 06. 03.) 댓글수 : 7
# 8 카시트 잘 태우기에 대한 이야기 댓글수 : 25
# 9 미국 여행시 에어비앤비/민박은 주의하시길 바랍니다. - 도시법/규정 문제 댓글수 : 29
# 10 LED스트립만 연결해서 모니터 앰비언트를 만들어보자. 댓글수 : 7
# 11 [주간 코로나] 05월 5주 - 통계편 - <통권 147호> 댓글수 : 4
# 12 상남자의 sata ssd2개 레이드0 비교기 (바이오스 vs 윈도우 2종) 댓글수 : 16
# 13 대란에 ssd를 샀어요 방열판 꼭 달아야 하나요? 구리를 사야해요? 알루미늄 사야해요? 댓글수 : 21
# 14 존윅4 불꽃샷건을 장난감총으로 따라해 보자 댓글수 : 10
# 15 [팁] 1분 안에 키보드 청소하는 법 댓글수 : 25
# 16 써멀구리스의 중요성 댓글수 : 12
# 17 포토샵 뺨치는 짭토샵 인공지능.GIF 댓글수 : 37
# 18 외국 느낌의 데스크셋업 만들기 댓글수 : 59
# 19 개인적인 영어 학습법입니다. 댓글수 : 14
# 20 제네시스, 스마트폰을 차키로! 디지털 키 등록 방법 A to Z 댓글수 : 9
# 21 인공지능으로 윤석열 제거하기.JPG 댓글수 : 33
# 22 Part3>영어 독해력을 키운다? 원서를 읽는 고행을 결심한 소수의 사람들에게 댓글수 : 19
# 23 알리발 더스트건 간단사용후기 댓글수 : 48
# 24 서울시 경계경보 담당자를 위한 경계경보 발령 강좌 댓글수 : 14
# 25 [코로나 정보] 코로나19 대응 지침 개정 댓글수 : 12
# ...

# %%
4단계: 타이틀별 링크 추가하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0

for title in titles:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            print(index,title_text.get_text().strip(),"댓글수 :",title_replies.get_text(),"\n","링크 :",title_link_url)
        except Exception as e:
            if title_replies == None:
                print(index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :",title_link_url)
            continue
# Out:
# 1 공부 13편 ㅡ 공부에서 중요한 것 댓글수 : 0
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18129880%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 2 뒤늦은 코로나 발병기 댓글수 : 9
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18128667%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 3 유니티로 간단한 게임 만들기 댓글수 : 18
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18128206%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 4 차에서 태블릿 사용 / 발열문제 해결책 댓글수 : 10
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18127635%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 5 chatgpt에서 만든 마크다운을 마인드맵으로 간단하게 사용하기 댓글수 : 2
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18125420%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 6 싱가포르 한주간 여행 후기겸 개인적 팁 댓글수 : 40
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18123296%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 7 [주간 코로나] 05월 5주 - 분석편 - (05. 28. - 06. 03.) 댓글수 : 7
# ...

# %%
5단계: 타이틀별 댓글 가져와서 출력하기
전 타이틀에 대한 댓글을 모두 가져오면, 실행시 시간이 매우 많이 걸리고, 서버에 무리가 되므로, 상위 5개만 테스트해보기 빈번한 크롤링은 사이트에서 안정성을 위해, 임의로 막을 수 있습니다

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            print(index,title_text.get_text().strip(),"댓글수 :",title_replies.get_text(),"\n","링크 :",
                  title_link_url)
        except Exception as e:
            if title_replies == None:
                print(index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :",title_link_url)
            continue
       
        for reply_text in title_in_reply:
            print("댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t",""))
# Out:
# 1 공부 13편 ㅡ 공부에서 중요한 것 댓글수 : 0
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18129880%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 2 뒤늦은 코로나 발병기 댓글수 : 9
#  링크 : https://davelee-fun.github.io/trial/board/lecture/18128667%EF%B9%96od=T31&po=0&category=0&groupCd=.html
# 댓글 :  코로나, 이제는 비급여인가요??
# 댓글 :  @아디프렌님 그런가봅니다
# 댓글 :  전 작년 12월에 코로나 걸렸을 때 기침은 2달정도 가다가 어느순간 없어지더군요. 다른 증상들은 금방 지나가더라구요. 참 전 목아프고그런건 없었네요. 이때 코감기약 코메키나가 효과가 좋아서 그뒤로도 코감기 증상있으면 한두번 먹으면 금방 없어 지더라구요. 그때 산 10캡슐이아직도 4캡슐 남았네요.빠른 쾌유를...
# 댓글 :  저는 딴 건 그러려니 하는데 목을 칼로 난도질한 듯한 통증이 제일 힘들었습니다
# 댓글 :  @Exhaust님 저는 다행히 이런통증과, 냄새 못맡는 증상이 덜하네요.
# 댓글 :  집안에 코로나 환자가 발생하면 제 아무리 잘 단속을 해도 가족 모두에게 전염됩니다.부인이 만삭이라시니, 가능하면 처가쪽이든 친가쪽이든피신이 좋겠습니다.(한가정내 모든 감염 사태 경험자입니다)
# 댓글 :  @NiCo-K님 네 피신해있는중입니다. 제가 나와있습니다
# 댓글 :  저랑 비슷하시네요. 저도 목요일부터 이상증상이 있어 금요일에 검사하고 첫 코로나 확진 받았어요. 저는 골고루 증상이 다 발현되는중이네요. 빠른 쾌차 하시길.
# ...

# %%
6단계: 엑셀로 저장하기
No, 게시글제목, 댓글 로 게시글 제목과 댓글 수 를 저장하기
그 다음 라인부터는 해당 게시글의 댓글을 댓글 셀에 저장하기
최초 10개의 게시글에 대해서만 작성해보기 (공지 포함)

# %%
import requests, openpyxl
from bs4 import BeautifulSoup

#엑셀
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active

# active 시트 이름 변경
excel_sheet.title = 'toy_crawling'
header=["No","타이틀 설명","댓글수"]
excel_sheet.append(header)
excel_sheet.column_dimensions['A'].width= 20
excel_sheet.column_dimensions['B'].width= 100
excel_sheet.column_dimensions['C'].width= 20


#크롤링 
res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            title_data = [index,title_text.get_text().strip(),"댓글수 :",title_replies.get_text(),"\n","링크 :",
                  title_link_url]
            excel_sheet.append(title_data)
        except Exception as e:
            if title_replies == None:
                title_data =[index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :",title_link_url]
                excel_sheet.append(title_data)
            continue
       
        for reply_text in title_in_reply:
            title_data_reply = ["댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t","")]
            excel_sheet.append(title_data_reply)
            
            
excel_file.save('crawling_excel.xlsx')
excel_file.close()

# %% [markdown]
# 7단계: 자동 줄바꿈과 볼드체 폰트 적용하기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
from openpyxl.styles import Alignment, Font

#엑셀
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
#폰트,정렬등 엑셀 설정
wrap_alignment = Alignment(wrap_text=True)
bold_font = Font(bold=True)
header_font = Font(bold=True, size=20)

# active 시트 이름 변경
excel_sheet.title = 'toy_crawling'
header=["No","타이틀 설명","댓글수"]
#header 글씨만 bold설정, 및 글씨 크기 키움
for cell in excel_sheet[1]:
    cell.font = header_font
#excel에 append로 넣기, dimensions로 cell(column)넓이지정
excel_sheet.append(header)
excel_sheet.column_dimensions['A'].width= 20
excel_sheet.column_dimensions['B'].width= 100
excel_sheet.column_dimensions['C'].width= 20

#크롤링 
res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0
row = 2

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        

        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            title_data = [index,title_text.get_text().strip(),"댓글수 :",title_replies.get_text(),"\n","링크 :",
                  title_link_url]
            excel_sheet.append(title_data)
            
            #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = bold_font
            row += 1
        except Exception as e:
            if title_replies == None:
                title_data =[index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :",title_link_url]
                excel_sheet.append(title_data)
            continue
       
        #타이틀에 달린 댓글내용들만 셀렉해오기위해 설정
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
        
        for reply_text in title_in_reply:
            title_data_reply = ["댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t","")]
            excel_sheet.append(title_data_reply)
            #댓글 정렬
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
            row += 1
            
            
excel_file.save('crawling_excel.xlsx')
excel_file.close()

# %%
8단계: 링크 넣기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
from openpyxl.styles import Alignment, Font

#엑셀
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
#폰트,정렬등 엑셀 설정
wrap_alignment = Alignment(wrap_text=True)
bold_font = Font(bold=True)
header_font = Font(bold=True, size=14)

# active 시트 이름 변경
excel_sheet.title = 'toy_crawling'
header=["No","타이틀 설명","댓글수"]
#header 글씨만 bold설정, 및 글씨 크기 키움
for cell in excel_sheet[1]:
    cell.font = header_font
#excel에 append로 넣기, dimensions로 cell(column)넓이지정
excel_sheet.append(header)
excel_sheet.column_dimensions['A'].width= 20
excel_sheet.column_dimensions['B'].width= 100
excel_sheet.column_dimensions['C'].width= 20

#크롤링 
res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0
row = 3

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            title_data = [index,title_text.get_text().strip().replace(" ",""),"댓글수 :",title_replies.get_text()]
            excel_sheet.append(title_data)
            #타이틀에 링크 추가
            excel_sheet.cell(row=row,column = 2).hyperlink = title_link_url
            #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = bold_font
            row += 1
            
        except Exception as e:
            if title_replies == None:
                title_data =[index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :"]
                excel_sheet.append(title_data)
                excel_sheet.cell(row=row,column = 2).hyperlink = title_link_url
                #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = bold_font
            row += 1
            continue
       
        #타이틀 관련 댓글들 크롤링                                                            
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
                                                                      
        for reply_text in title_in_reply:
            title_data_reply = ["댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t","")]
            excel_sheet.append(title_data_reply)
            #댓글 정렬
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
            row += 1
            
            
excel_file.save('crawling_excel.xlsx')
excel_file.close()

# %%
9 단계: 링크를 가진 게시글 제목 색상과 밑줄 넣기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
from openpyxl.styles import Alignment, Font , colors

#엑셀
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
#폰트,정렬등 엑셀 설정
wrap_alignment = Alignment(wrap_text=True)
bold_font = Font(bold=True)
header_font = Font(bold=True, size=14)
#링크 컬러
link_font = Font(color=colors.BLUE, underline="single",bold=True, size =16)


# active 시트 이름 변경
excel_sheet.title = 'toy_crawling'
header=["No","타이틀 설명","댓글수"]
#header 글씨만 bold설정, 및 글씨 크기 키움
for cell in excel_sheet[1]:
    cell.font = header_font
    
#excel에 append로 넣기, dimensions로 cell(column)넓이지정
excel_sheet.append(header)
excel_sheet.column_dimensions['A'].width= 20
excel_sheet.column_dimensions['B'].width= 100
excel_sheet.column_dimensions['C'].width= 20

#크롤링 
res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0
row = 3

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            title_data = [index,title_text.get_text().strip().replace(" ",""),"댓글수 :",title_replies.get_text()]
            excel_sheet.append(title_data)
            #타이틀에 링크 추가
            excel_sheet.cell(row=row,column = 2).hyperlink = title_link_url
            #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = link_font
            row += 1
            
        except Exception as e:
            if title_replies == None:
                title_data =[index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :"]
                excel_sheet.append(title_data)
                excel_sheet.cell(row=row,column = 2).hyperlink = title_link_url
                #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = link_font
            row += 1
            continue
       
        #타이틀 관련 댓글들 크롤링                                                            
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
                                                                      
        for reply_text in title_in_reply:
            title_data_reply = ["댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t","")]
            excel_sheet.append(title_data_reply)
            #댓글 정렬
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
            row += 1
            
            
excel_file.save('crawling_excel.xlsx')
excel_file.close()

# %%
10단계: 셀에 border (선) 넣고, 게시글제목 행 색상 넣기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup
from openpyxl.styles import Alignment, Font , colors, Border, Side, PatternFill

#엑셀
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
#폰트,정렬등 엑셀 설정
wrap_alignment = Alignment(wrap_text=True)
bold_font = Font(bold=True)
header_font = Font(bold=True, size=14)
#링크 컬러
link_font = Font(color=colors.BLUE, underline="single",bold=True, size =16)
#셀에 들어갈 색상
cell_fill = PatternFill(start_color='D3D3D3', end_color='D3D3D3', fill_type='solid')
#보더 설정
thin_border = Border(left=Side(style='thin'), 
                     right=Side(style='thin'), 
                     top=Side(style='thin'), 
                     bottom=Side(style='thin'))


# active 시트 이름 변경
excel_sheet.title = 'toy_crawling'
header=["No","타이틀 설명","댓글수"]
#excel에 append로 넣기, 
excel_sheet.append(header)
#header 글씨만 bold설정, 및 글씨 크기 키움
for cell in excel_sheet[1]:
    cell.font = header_font
    cell.border = thin_border
    cell.fill = cell_fill
#dimensions로 cell(column)넓이지정
excel_sheet.column_dimensions['A'].width= 20
excel_sheet.column_dimensions['B'].width= 100
excel_sheet.column_dimensions['C'].width= 20

#크롤링 
res = requests.get('https://davelee-fun.github.io/trial/board/lecture')
soup = BeautifulSoup(res.content, 'html.parser')
titles = soup.select('div.list_item')
index = 0
row = 3

#다섯개만 가져오기
for title in titles[3:9]:
    title_text = title.select_one('span.subject_fixed')
    title_replies = title.select_one('span.rSymph05')
    title_link = title.select_one('a.list_subject')
    common_url = 'https://davelee-fun.github.io/trial/board/'
    
    #Nonetype object 에러가 뜨지 않기위해 if문으로 제약조건을 걸어서 데이터가 없는경우 출력 X
    if title_text != None:
        #데이터가 없는경우는 출력하지않기위해서 제약조건에 맞는경우에만 Index번호가 1씩증가하도록 설정
        index += 1
        title_link_url = 'https://davelee-fun.github.io/trial/board/' + title_link['href']
        
        #댓글이 없는 경우 Nonetype이 되지않기위해 try catch로 감싸서 주고 None인 경우에는 0으로 출력되기 설정
        try:
            title_data = [index,title_text.get_text().strip().replace(" ",""),"댓글수 :",title_replies.get_text()]
            excel_sheet.append(title_data)
            #타이틀에 링크 추가
            excel_sheet.cell(row=row,column = 2).hyperlink = title_link_url
            #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = link_font
                cell.border = thin_border
            row += 1
            
        except Exception as e:
            if title_replies == None:
                title_data =[index,title_text.get_text().strip(),"댓글수 :",0,"\n","링크 :"]
                excel_sheet.append(title_data)
                excel_sheet.cell(row=row,column = ).hyperlink = title_link_url
                #두번째 row를 for문을 통해서 정렬과,bold
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.font = link_font
                cell.border = thin_border
            row += 1
            continue
       
        #타이틀 관련 댓글들 크롤링                                                            
        res_reply = requests.get(title_link_url)
        res_reply_soup = BeautifulSoup(res_reply.content, 'html.parser')
        title_in_reply = res_reply_soup.select('div.comment_content')
                                                                      
        for reply_text in title_in_reply:
            title_data_reply = ["댓글 : ",reply_text.get_text().strip().replace("\n","").replace("\t","")]
            excel_sheet.append(title_data_reply)
            #댓글 정렬
            for cell in excel_sheet[row]:
                cell.alignment = wrap_alignment
                cell.border = thin_border
            row += 1
            
            
excel_file.save('crawling_excel.xlsx')
excel_file.close()
